# %% [markdown]
# ## Import the Data
# Choose a public data set from the list below or provide a URL to your own data

# %%
import acquireData as display
display.renderDataSources()

# %% [markdown]
# ## Inspect the Data
# Now load the data in a table and llok at the values

# %%
display.renderData()
# Out:
#       Draw Date    Winning Numbers  Multiplier
# 0    02/03/2010  17 22 36 37 52 24         2.0
# 1    02/06/2010  14 22 52 54 59 04         3.0
# 2    02/10/2010  05 08 29 37 38 34         5.0
# 3    02/13/2010  10 14 30 40 51 01         4.0
# 4    02/17/2010  07 08 19 26 36 15         3.0
# 5    02/20/2010  13 27 37 41 54 32         2.0
# 6    02/24/2010  04 17 35 50 57 12         2.0
# 7    02/27/2010  18 47 51 53 58 30         2.0
# 8    03/03/2010  07 09 14 45 49 23         4.0
# 9    03/06/2010  10 29 33 41 59 15         2.0
# 10   03/10/2010  17 21 37 41 50 01         2.0
# 11   03/13/2010  06 16 20 31 36 08         5.0
# 12   03/17/2010  24 26 45 48 55 08         2.0
# 13   03/20/2010  09 36 39 44 45 09         2.0
# 14   03/24/2010  14 20 24 39 49 07         3.0
# 15   03/27/2010  07 21 32 44 52 10         4.0
# 16   03/31/2010  05 13 17 45 54 12         5.0
# 17   04/03/2010  10 15 31 52 59 04         4.0
# 18   04/07/2010  04 36 40 44 52 33         2.0
# ...
