# %%
import requests
import urllib.request
from bs4 import BeautifulSoup
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from collections import defaultdict
from string import punctuation
from heapq import nlargest
#from math import log
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# %%
class FrequencySummarizer:
    def __init__(self,min_cut=0.1,max_cut=0.9):
        self._min_cut = min_cut
        self._max_cut = max_cut
        self._stopwords = set(stopwords.words('english') +
                              list(punctuation) +
                              [u"'s",'"'])
    
    def _compute_frequencies(self,word_sent,customStopWords=None):
        freq = defaultdict(int)
        if customStopWords is None:
            stopwords = set(self._stopwords)
        else:
            stopwords = set(customStopWords).union(self._stopwords)
        for sentence in word_sent:
            for word in sentence:
                if word not in stopwords:
                    freq[word] += 1
        m = float(max(freq.values()))
        for word in list(freq.keys()):
            freq[word] = freq[word]/m
            if freq[word] >= self._max_cut or freq[word] <= self._min_cut:
                del freq[word]
        return freq
    
    def extractFeatures(self,article,n,customStopWords=None):
        text = article[0]
        title = article[1]
        sentences = sent_tokenize(text)
        word_sent = [word_tokenize(s.lower()) for s in sentences]
        self._freq = self._compute_frequencies(word_sent,customStopWords)
        if n < 0:
            return nlargest(len(self._freq_keys()),self._freq,key=self._freq.get)
        else:
            return nlargest(n,self._freq,key=self._freq.get)
    
    def extractRawFrequencies(self, article):
        text = article[0]
        title = article[1]
        sentences = sent_tokenize(text)
        word_sent = [word_tokenize(s.lower()) for s in sentences]
        freq = defaultdict(int)
        for s in word_sent:
            for word in s:
                if word not in self._stopwords:
                    freq[word] += 1
        return freq
    
    def summarize(self, article,n):
        text = article[0]
        title = article[1]
        sentences = sent_tokenize(text)
        word_sent = [word_tokenize(s.lower()) for s in sentences]
        self._freq = self._compute_frequencies(word_sent)
        ranking = defaultdict(int)
        for i,sentence in enumerate(word_sent):
            for word in sentence:
                if word in self._freq:
                    ranking[i] += self._freq[word]
        sentences_index = nlargest(n,ranking,key=ranking.get)

        return [sentences[j] for j in sentences_index]

# %%
def getDoxyDonkeyText(testUrl,token):
    response = requests.get(testUrl)
    soup = BeautifulSoup(response.content, "html5lib")
    page = str(soup)
    title = soup.find("title").text
    mydivs = soup.findAll("div", {"class":token})
    text = ''.join(map(lambda p:p.text,mydivs))
    return text,title

def getAllDoxyDonkeyPosts(url,links):
    request = urllib.request.Request(url)
    response = urllib.request.urlopen(request)
    soup = BeautifulSoup(response, "html5lib")
    for a in soup.findAll('a'):
        try:
            url = a['href']
            title = a['title']
            if title == "Older Posts":
                print(title, url)
                links.append(url)
                getAllDoxyDonkeyPosts(url,links)
        except:
            title = ""
    return

# %%
blogUrl = "http://doxydonkey.blogspot.in"
links = []
getAllDoxyDonkeyPosts(blogUrl,links)
doxyDonkeyPosts = {}
for link in links:
    doxyDonkeyPosts[link] = getDoxyDonkeyText(link,'post-body')


documentCorpus = []
for onePost in doxyDonkeyPosts.values():
    documentCorpus.append(onePost[0])
# Out:
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2017-05-23T19:53:00-07:00&max-results=7
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2017-05-14T19:02:00-07:00&max-results=7&start=7&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2017-05-02T19:43:00-07:00&max-results=7&start=14&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2017-04-17T19:26:00-07:00&max-results=7&start=21&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2017-04-10T18:56:00-07:00&max-results=7&start=28&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2017-03-30T19:57:00-07:00&max-results=7&start=35&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2017-03-20T19:47:00-07:00&max-results=7&start=42&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2017-03-02T17:42:00-08:00&max-results=7&start=49&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2017-02-21T19:13:00-08:00&max-results=7&start=56&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2017-02-12T18:34:00-08:00&max-results=7&start=63&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2017-02-01T18:56:00-08:00&max-results=7&start=70&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2017-01-22T18:58:00-08:00&max-results=7&start=77&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2017-01-11T18:09:00-08:00&max-results=7&start=84&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2017-01-02T17:59:00-08:00&max-results=7&start=91&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2016-12-22T18:58:00-08:00&max-results=7&start=98&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2016-12-13T18:57:00-08:00&max-results=7&start=105&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2016-12-04T18:58:00-08:00&max-results=7&start=112&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2016-09-09T07:34:00-07:00&max-results=7&start=119&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2016-08-28T20:08:00-07:00&max-results=7&start=126&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2016-08-17T19:24:00-07:00&max-results=7&start=133&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2016-08-07T20:30:00-07:00&max-results=7&start=140&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2016-07-26T19:55:00-07:00&max-results=7&start=147&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2016-07-17T19:47:00-07:00&max-results=7&start=154&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2016-07-06T19:34:00-07:00&max-results=7&start=161&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2016-06-26T19:36:00-07:00&max-results=7&start=168&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2016-06-15T19:23:00-07:00&max-results=7&start=175&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2016-06-06T18:50:00-07:00&max-results=7&start=182&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2016-05-26T20:08:00-07:00&max-results=7&start=189&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2016-05-17T18:52:00-07:00&max-results=7&start=196&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2016-05-06T19:26:00-07:00&max-results=7&start=203&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2016-04-27T19:03:00-07:00&max-results=7&start=210&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2016-04-19T19:36:00-07:00&max-results=7&start=217&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2016-04-10T19:19:00-07:00&max-results=7&start=224&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2016-03-30T19:12:00-07:00&max-results=7&start=231&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2016-03-20T18:41:00-07:00&max-results=7&start=238&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2016-03-09T18:38:00-08:00&max-results=7&start=245&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2016-02-28T17:47:00-08:00&max-results=7&start=252&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2016-02-17T18:44:00-08:00&max-results=7&start=259&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2016-02-08T18:13:00-08:00&max-results=7&start=266&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2016-01-28T19:45:00-08:00&max-results=7&start=273&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2016-01-18T18:30:00-08:00&max-results=7&start=280&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2016-01-07T19:03:00-08:00&max-results=7&start=287&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-12-28T18:26:00-08:00&max-results=7&start=294&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-12-16T18:24:00-08:00&max-results=7&start=301&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-12-07T18:24:00-08:00&max-results=7&start=308&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-11-26T17:49:00-08:00&max-results=7&start=315&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-11-17T18:18:00-08:00&max-results=7&start=322&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-11-05T20:15:00-08:00&max-results=7&start=329&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-10-27T20:04:00-07:00&max-results=7&start=336&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-10-12T19:45:00-07:00&max-results=7&start=343&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-09-30T19:33:00-07:00&max-results=7&start=350&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-09-20T19:11:00-07:00&max-results=7&start=357&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-09-09T19:32:00-07:00&max-results=7&start=364&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-08-31T19:31:00-07:00&max-results=7&start=371&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-08-20T19:29:00-07:00&max-results=7&start=378&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-08-11T19:32:00-07:00&max-results=7&start=385&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-08-02T19:04:00-07:00&max-results=7&start=392&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-07-22T19:39:00-07:00&max-results=7&start=399&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-07-13T19:38:00-07:00&max-results=7&start=406&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-07-02T21:15:00-07:00&max-results=7&start=413&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-06-23T19:30:00-07:00&max-results=7&start=420&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-06-14T19:36:00-07:00&max-results=7&start=427&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-06-02T19:38:00-07:00&max-results=7&start=434&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-05-24T20:16:00-07:00&max-results=7&start=441&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-05-13T20:18:00-07:00&max-results=7&start=448&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-05-04T20:23:00-07:00&max-results=7&start=455&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-04-23T20:19:00-07:00&max-results=7&start=462&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-04-14T19:40:00-07:00&max-results=7&start=469&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-04-05T20:22:00-07:00&max-results=7&start=476&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-03-24T20:12:00-07:00&max-results=7&start=483&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-03-15T20:41:00-07:00&max-results=7&start=490&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-03-03T19:30:00-08:00&max-results=7&start=497&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-02-22T19:55:00-08:00&max-results=7&start=504&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-02-11T20:02:00-08:00&max-results=7&start=511&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-02-02T19:46:00-08:00&max-results=7&start=518&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-01-22T19:50:00-08:00&max-results=7&start=524&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-01-15T19:17:00-08:00&max-results=7&start=529&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2015-01-06T19:48:00-08:00&max-results=7&start=536&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2014-12-25T21:30:00-08:00&max-results=7&start=543&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2014-12-15T19:24:00-08:00&max-results=7&start=550&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2014-12-05T01:52:00-08:00&max-results=7&start=557&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2014-11-26T01:44:00-08:00&max-results=7&start=564&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2014-11-17T01:41:00-08:00&max-results=7&start=571&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2014-11-06T01:38:00-08:00&max-results=7&start=578&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2014-10-28T01:24:00-07:00&max-results=7&start=585&by-date=false
# Older Posts http://doxydonkey.blogspot.sg/search?updated-max=2014-10-17T01:20:00-07:00&max-results=7&start=592&by-date=false

# %%
vectorizer = TfidfVectorizer(max_df=0.5,min_df=2,stop_words='english')
X = vectorizer.fit_transform(documentCorpus)
km = KMeans(n_clusters = 5, init = 'k-means++', max_iter = 100, n_init = 1, verbose = True)
km.fit(X)

keywords = {}
for i,cluster in enumerate(km.labels_):
    oneDocument = documentCorpus[i]
    fs = FrequencySummarizer()
    summary = fs.extractFeatures((oneDocument,""),
                                100,
                                [u"according",u"also",u"billion",u"like",u"new", u"one",u"year",u"first",u"last"])
    if cluster not in keywords:
        keywords[cluster] = set(summary)
    else:
        keywords[cluster] = keywords[cluster].intersection(set(summary))

for cluster in keywords.keys():
    print ("Cluster", cluster, "\nKeywords",keywords[cluster])
# Out:
# Initialization complete
# Iteration  0, inertia 137.600
# Iteration  1, inertia 71.707
# Converged at iteration 1: center shift 0.000000e+00 within tolerance 7.273563e-09
# Cluster 0
# Keywords {'company', '”', 'business', 'million', 'percent', '“', 'said'}
# Cluster 1
# Keywords {'would', 'said', 'million'}
# Cluster 2
# Keywords {'“', 'company', '”', 'said', 'million'}
# Cluster 3
# Keywords {'percent', 'said'}
# Cluster 4
# Keywords {'percent', '“', 'company', '”', 'said'}
